# %% [markdown]
# # Transformada de Fourier
#
# La idea es usar esta libreta electrónica para calcular la transformada de Fourier y estudiar los efectos de sampleo.

# %%
import matplotlib.pyplot as plot
import numpy as np
import numpy.fft as fft
# %matplotlib inline 

a = 2.0
N = 10000
x = np.linspace(0, a, N)
fx = np.sin(3.75*2*np.pi*x / a  ) + np.sin(12.5*2*np.pi*x / a  )
plot.plot(x,fx)
plot.show()

# %%
def fxfourier(ω):
    N = len(fx)
    n = np.arange(N)
    a =(2/N)*1/(2*np.pi)**(1/2)
    M=a*np.exp(-2j * np.pi * ω * n / N)
    return np.dot(M, fx)


frange=range(0,200)
freqf=[fxfourier(0.1*x) for x in frange]

# %%
plot.plot(0.1*np.asarray(frange),np.abs(freqf))

# %%
frange=range(0,1000)
freqf=[fxfourier(x) for x in frange]

frange=range(0,1000)
freqf=[fxfourier(x) for x in frange]

# %%
fq=np.asarray(freqf)
pw=np.log10(fq.imag**2+fq.imag**2)
plot.plot(frange,pw)
plot.show()
# Out:
# /home/selim/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:2: RuntimeWarning: divide by zero encountered in log10
#   from ipykernel import kernelapp as app

# %%
abs(audiofourier(645))
# Out:
# 37.886249304288057

# %%
O= 10**4
olist = np.linspace(-O, O, 10**4)
tildefo = audiofourier(olist)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-168-ff0549bcacbb> in <module>()
#       1 O= 10**4
#       2 olist = np.linspace(-O, O, 10**4)
# ----> 3 tildefo = audiofourier(olist)
#
# <ipython-input-166-714ffe015499> in audiofourier(ω)
#       3     n = np.arange(N)
#       4     a =(2/N)*1/(2*np.pi)**(1/2)
# ----> 5     M=a*np.exp(-2j * np.pi * ω * n / N)
#       6     return np.dot(M, audio)
#       7
#
# ValueError: operands could not be broadcast together with shapes (10000,) (270646,)

# %%
O= 10**4
olist = np.linspace(-O, O, 10**4)
tildefo = fourier(audio, olist)
plot.plot(tildefo)
plot.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-155-7f19ab295668> in <module>()
#       1 O= 10**4
#       2 olist = np.linspace(-O, O, 10**4)
# ----> 3 tildefo = fourier(audio, olist)
#       4 plot.plot(tildefo)
#       5 plot.show()
#
# <ipython-input-152-199aea3c505c> in fourier(f, ω)
#       3     n = np.arange(N)
#       4     a =(2/N)*1/(2*np.pi)**(1/2)
# ----> 5     M=a*np.exp(-2j * np.pi * ω * n / N)
#       6     return np.dot(M, f)
#       7
#
# ValueError: operands could not be broadcast together with shapes (10000,) (270646,)

# %%
fftx=abs(fft.fft(fx))
plot.plot(10*np.log10(fftx))

# %% [markdown]
# Ahora leemos el archivo de audio y graficamos la forma de onda.

# %%
from scipy.io import wavfile
 
# read audio samples


input_data = wavfile.read("adist.wav")
audio = input_data[1]
samplerate = input_data[0]
times = np.arange(len(audio))/float(samplerate)


# plot the waveforme vs time
plot.plot(times, audio)
# label the axes
plot.ylabel("Amplitude")
plot.xlabel("Time(s)")
# set the title  
plot.title("Audio Waveform")
# display the plot
plot.show()

# %%
audiofourier(1000)
def audiofourier(ω):
    N = len(audio)
    n = np.arange(N)
    a =(2/N)*1/(2*np.pi)**(1/2)
    M=a*np.exp(-2j * np.pi * ω * n / N)
    return np.dot(M, audio)

audiofourier(1000)

# %%
freqs=abs(np.fft.fft(audio))/len(audio)
freqs=freqs**2

plot.plot(10*np.log10(freqs))
plot.show()

# %%
def dft(x, ω):
    N = len(audio)
    n = np.arange(N)
    a =(2/N)*1/(2*np.pi)**(1/2)
    M=a*np.exp(-2j * np.pi * ω * n / N)
    return np.dot(M, x)

dft(audio,100000)
# Out:
# (0.06371873844090542-0.052673313231008212j)

# %%
N
# Out:
# 88200

# %%
def dft(x):
    """Compute the discrete Fourier Transform of the 1D array x"""
    x = np.asarray(x, dtype=float)
    N = x.shape[0]
    n = np.arange(N)
    k = n.reshape((N, 1))
    M = np.exp(-2j * np.pi * k * n / N)
    return np.dot(M, x)

x = np.random.random(1024)
dft_slow(x), np.fft.fft(x)
# Out:
# (array([ 509.62839369 +0.j        ,    5.02608949 -8.19438322j,
#           -7.84839013+14.3358214j , ...,  -12.66716710 +0.75613411j,
#           -7.84839013-14.3358214j ,    5.02608949 +8.19438322j]),
#  array([ 509.62839369 +0.j        ,    5.02608949 -8.19438322j,
#           -7.84839013+14.3358214j , ...,  -12.66716710 +0.75613411j,
#           -7.84839013-14.3358214j ,    5.02608949 +8.19438322j]))

# %%
dft_slow(audio)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-95-f57f10e5c8c0> in <module>()
# ----> 1 dft_slow(audio)
#
# <ipython-input-72-9fbf6ac2c9cf> in dft_slow(x)
#       5     n = np.arange(N)
#       6     k = n.reshape((N, 1))
# ----> 7     M = np.exp(-2j * np.pi * k * n / N)
#       8     return np.dot(M, x)
#       9
#
# MemoryError:

# %%
ω=np.arange(len(audio))
M = np.exp(-2j*np.pi*ω*n/ N)

np.dot(ω, audio)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-55-4ea108745969> in <module>()
#       1 ω=np.arange(len(audio))
# ----> 2 M = np.exp(-2*j*np.pi*ω*n/ N)
#       3
#       4 np.dot(ω, audio)
#
# NameError: name 'j' is not defined
